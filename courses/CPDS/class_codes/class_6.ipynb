# %% [markdown]
# Assignment 26: str
#
# 1. Write a Python script to check if a given string
#    has only alphabets in it.
#
# 2. Write a Python script to check if a given character
#    is present in a given string or not.
#
# 3. Write a Python script to count vowels in a given string.
#
# 4. Write a Python script to count words in a given string.
#
# 5. Write a Python script to reverse a string.

# %%
s = "msc"

# %%
s.isalpha()
# Out:
# True

# %%
"msc" in s
# Out:
# True

# %%
len(s)
# Out:
# 3

# %%
s = "I am a Masters student"

# %%
s.split()
# Out:
# ['I', 'am', 'a', 'Masters', 'student']

# %%
"-".join(s.split())
# Out:
# 'I-am-a-Masters-student'

# %%
sum([1 for ch in s])
# Out:
# 22

# %%
"apple" and "banana"
# Out:
# 'banana'

# %% [markdown]
# function handles - lambda
#
# function_name = lambda inputs: body

# %% [markdown]
# def function_name(input):
#
# $~~$ body
#
# $~~$ return

# %%
reverss_s = lambda s: s and s[:-1]+reverss_s(s[:-1])

# %%
reverss_s("apple")
# Out:
# 'applappapa'

# %%
reverss_s = lambda s: s and s[-1]+reverss_s(s[:-1])

# %%
reverss_s("apple")
# Out:
# 'elppa'

# %%
s = "apple"

# %%
s[::-1]
# Out:
# 'elppa'

# %% [markdown]
# Assignment 27: More on str
#
# 1. Write a Python script to reverse a string word-wise.
#
#    Example:
#    "mysirg education services"
#
#    Result:
#    "services education mysirg"
#
# 2. Write a Python script to extract numbers from a given text
#    and store all the numbers in a list.
#
# 3. Write a Python script to check whether a string
#    is a palindrome or not.
#
# 4. Write a Python script to transform a given string
#    to uppercase.
#
# 5. Write a Python script to find the maximum-length word
#    in a given text.

# %%
sentence = "mysirg education services"

# %%
" ".join(sentence.split()[::-1])
# Out:
# 'services education mysirg'

# %%
text = "siva1"

# %%
text = "mam"

# %%
print(text == text[::-1])
# Out:
# True

# %%
[ch for ch in text if ch.isdigit()]
# Out:
# ['1']

# %%
text.upper()
# Out:
# 'MAM'

# %%
sentence = "I am a master student"

# %%
max_len = max([len(string) for string in sentence.split()])

# %%
for word in sentence.split():
  if len(word)==max_len:
    print(word)
# Out:
# student

# %% [markdown]
# Assignment 28: List and str Mixed
#
# 1. Write a Python script to remove all non-int values
#    from a list.
#
# 2. Write a Python script to print distinct elements along
#    with their frequencies of occurrences in the list.
#
# 3. Write a Python script to sort a list of strings.
#
# 4. Write a Python script to find the first repeated string
#    in a list of strings.
#
# 5. Write a Python script to count strings which end
#    with the character 's' in a list of strings.

# %%
dummy_list = ["siva", "k", 1, 2, 3]

# %%
for elements in dummy_list:
  if type(elements) == int:
    dummy_list.remove(elements)

# %%
new_list =[]
for elements in dummy_list:
  if type(elements) == int:
    new_list.append(elements)

# %%
new_list
# Out:
# [1, 2, 3]

# %%
dummy_list,
# Out:
# ['siva', 'k', 2]

# %%
dummy_list = [1,2,3,4,5,1,2,3,1,2,3]

# %%
dummy_set = set(dummy_list)

# %%
dummy_set
# Out:
# {1, 2, 3, 4, 5}

# %%
frequency_list = []

# %%
for elemnets in dummy_set:
  count = 0
  for elements in dummy_list:
    if elements == elemnets:
      count+=1
  frequency_list.append(count)

# %%
frequency_list
# Out:
# [3, 3, 3, 1, 1]

# %%
name_of_people = ["siva", "ganesh", "madhan"]

# %%
"apple"<"aqple"
# Out:
# True

# %%
sorted(name_of_people)
# Out:
# ['ganesh', 'madhan', 'siva']

# %%
print(ord('s'))
# Out:
# 115

# %%
text = "apple"

# %%
text_set=set([ch for ch in text])

# %%
for ch1 in text_set:
  count = 0
  for ch2 in text:
    if ch1 ==ch2:
      count+=1
    if count >=2:
      print(ch1)
      break
# Out:
# p

# %%
sentence = "I am having class of MSC AM and MSC SC"

# %%
set(sentence.split())
# Out:
# {'AM', 'I', 'MSC', 'SC', 'am', 'and', 'class', 'having', 'of'}

# %%
sentence.split()
# Out:
# ['I', 'am', 'having', 'class', 'of', 'MSC', 'AM', 'and', 'MSC', 'SC']

# %%
for word1 in set(sentence.split()):
  count =0
  for word2 in sentence.split():
    if word1 == word2:
      count+=1
    if count >=2:
      print(word1)
      break
# Out:
# MSC

# %%
dummy_list = ['dogs', 'cats', 'dog']

# %%
text = "dogs"
text.endswith('s')
# Out:
# True

# %%
[string for string in dummy_list if string.endswith('s')]
# Out:
# ['dogs', 'cats']

# %%
dummy_list = ['dogs', 'cats', 'dog', 12]

# %%
[string for string in dummy_list if type(string)==str if string.endswith('s')]
# Out:
# ['dogs', 'cats']

# %% [markdown]
# Assignment 29: Tuple
#
# 1. Write a Python script to create a tuple from a given list.
#
# 2. Write a Python script to reverse a tuple.
#
# 3. Write a Python script to create a list of tuples from
#    a given list of strings, where each tuple is a collection
#    of strings beginning with the same character.
#
# 4. Write a Python script to create a list of tuples,
#    where each tuple is a pair of elements:
#    first element is an uppercase character and
#    second element is its Unicode.
#
# 5. Write a Python script to find the sum of all odd numbers
#    stored in a tuple.

# %%
(2,34)[0] =0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_867/3547268627.py in <cell line: 0>()
# ----> 1 (2,34)[0] =0
#
# TypeError: 'tuple' object does not support item assignment

# %%
dummy_list = [2,3]
dummy_list[0]=0

# %%
dummy_list
# Out:
# [0, 3]

# %%
tuple(dummy_list)
# Out:
# (0, 3)

# %%
tuple(dummy_list)[::-1]
# Out:
# (3, 0)

# %%
list_of_strings = ["apple", "banna"]

# %%
[(ele_from_str[0], ele_from_str) for ele_from_str in list_of_strings]
# Out:
# [('a', 'apple'), ('b', 'banna')]

# %%
[(ele_from_str[0], ord(ele_from_str[0])) for ele_from_str in list_of_strings]
# Out:
# [('a', 97), ('b', 98)]

# %%
dummy_tuple = (1,2,3,4,5,6,7,8,9)

# %%
sum([num for num in dummy_tuple if num%2!=0])
# Out:
# 25

# %% [markdown]
# Assignment 30: Set
#
# 1. Write a Python script to print all distinct elements
#    of a list. Use set to solve the problem.
#
# 2. Create two sets from a given set of numbers
#    to separate even and odd numbers.
#
# 3. Given a set of five player names, write a Python script
#    to form all possible pairs of players by selecting
#    two players at a time.
#
# 4. Given a list of candidates wearing black hats and
#    another list of candidates wearing red shoes,
#    find the candidates wearing both black hats
#    and red shoes.
#
# 5. Write a Python script to create a set of tuples,
#    where each tuple has two dice values.
#    Take N from the user and generate all possible tuples
#    such that the tuple elements sum to N.

# %%
set([1,2,1,2])
# Out:
# {1, 2}

# %%
players_name = {"A", "B", "C", "D", "E"}

# %%
[(player1, player2) for player1 in players_name for player2 in players_name if player1!=player2]
# Out:
# [('B', 'D'),
#  ('B', 'A'),
#  ('B', 'E'),
#  ('B', 'C'),
#  ('D', 'B'),
#  ('D', 'A'),
#  ('D', 'E'),
#  ('D', 'C'),
#  ('A', 'B'),
#  ('A', 'D'),
#  ('A', 'E'),
#  ('A', 'C'),
#  ('E', 'B'),
#  ('E', 'D'),
#  ('E', 'A'),
#  ('E', 'C'),
#  ('C', 'B'),
#  ('C', 'D'),
#  ('C', 'A'),
#  ('C', 'E')]

# %%
[(list(players_name)[i], list(players_name)[j])
for i in range(len(players_name))
for j in range(i+1,len(players_name))]
# Out:
# [('B', 'D'),
#  ('B', 'A'),
#  ('B', 'E'),
#  ('B', 'C'),
#  ('D', 'A'),
#  ('D', 'E'),
#  ('D', 'C'),
#  ('A', 'E'),
#  ('A', 'C'),
#  ('E', 'C')]
